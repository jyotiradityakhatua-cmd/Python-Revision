# %% [markdown]
# # Implicit

# %%
a=20
b=10.5
print(a+b)
# Out:
# 30.5

# %% [markdown]
# # Explicit type casting

# %%
a=int("10")
b=5
print(a+b)
# Out:
# 15

# %% [markdown]
# # Data types

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
a=5.0
print(type(a))
# Out:
# <class 'float'>

# %%
a="5"
print(type(a))
# Out:
# <class 'str'>

# %%
list=["jyotir","mohit","srijan",56,23,12.3,67.9,True,False]
print(type(list))
# Out:
# <class 'list'>

# %%
list.append(["jyotir"])

# %%
x = int(1)   
y = int(2.8) 
z = int("3") 
print(x+y+z)
# Out:
# 6

# %%
x = str("s1") 
y = str(2)    
z = str(3.0)  
print(x+y+z)
# Out:
# s123.0

# %%
a=True;
b=10.5;
c=a+b;

print (a+b+c);
# Out:
# 23.0

# %%
a=False
b=10.5
c=a+b
print(a+b+c)
# Out:
# 21.0

# %%
a=int(True)
type(a)
# Out:
# int

# %%
a = ("10"+"01")
b = ("10"+"01")
print(a+b)
# Out:
# 10011001

# %%
x={ 
    1:"raj",
    2:"Jayash",
    3:"sooraj"
}

y={4:"Rahul"}

x.update(y)
print(x)
# Out:
# {1: 'raj', 2: 'Jayash', 3: 'sooraj', 4: 'Rahul'}

# %%
a={"Rohit","Shyam"}
b={"Virat","Kohli"}
print(a|b)
# Out:
# {'Kohli', 'Shyam', 'Virat', 'Rohit'}

# %%
a={"Rohit","Shyam","Virat"}
b={"Virat","Kohli"}
print(a.union(b))
# Out:
# {'Kohli', 'Virat', 'Shyam', 'Rohit'}

# %%
a={"Rohit","Shyam","Virat"}
print(type(a))
# Out:
# <class 'set'>

# %%
x={ 
    1:"raj",
    2:"Jayash",
    3:"sooraj"
}
print(x)
# Out:
# {1: 'raj', 2: 'Jayash', 3: 'sooraj'}

# %%
list=["jyotir","mohit","srijan",56,23,12.3,67.9,True]
print(type(list))
# Out:
# <class 'list'>

# %%
tuple=list("rohit")
print(type(tuple))
print(tuple)
# Out:
# <class 'list'>
# ['r', 'o', 'h', 'i', 't']

# %%
tuple=("rohit")
print(type(tuple))
# Out:
# <class 'str'>

# %%
a=(7)
print(type(a))
# Out:
# <class 'int'>

# %%
b=(7.5)
print(type(b))
# Out:
# <class 'float'>

# %%
c=(True)
print(type(c))
# Out:
# <class 'bool'>

# %%
tuple=list("rohit")
print(type(tuple))
print(tuple)
# Out:
# <class 'list'>
# ['r', 'o', 'h', 'i', 't']

# %%
c="".join(tuple)
print(c)
# Out:
# rohit

# %%
a=set[23,12,23,3,3,3]
print(type(a))
# Out:
# <class 'types.GenericAlias'>

# %%
tuple=list("rohit")
print(type(tuple))
print(tuple)
# Out:
# <class 'list'>
# ['r', 'o', 'h', 'i', 't']

# %%
a=(23,12,23,3,3,3)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=[23,12,23,3,3,3].extend("rahul")
print(a)
# Out:
# None
