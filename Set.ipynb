# %%
set = {1, 2, 3, 4, 5}
print (set)
# Out:
# {1, 2, 3, 4, 5}

# %%
mixed_set = {1, 'hello', (1, 2, 3)}
print (mixed_set)
# Out:
# {1, 'hello', (1, 2, 3)}

# %%
my_set = {1, 2, 3, 3}

my_set.add(4)  
print (my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_set = {1, 2, 3, 4}

my_set.remove(3)  
print (my_set)
# Out:
# {1, 2, 4}

# %%
my_set = {1, 2, 3, 4}
if 2 in my_set:
   print("2 is present in the set")
else:
   print("2 is not present in the set")
# Out:
# 2 is present in the set

# %%
my_frozen_set = frozenset([1, 2, 3])
print(my_frozen_set) 
my_frozen_set.add(4)
# Out:
# frozenset({1, 2, 3})
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 my_frozen_set = frozenset([1, 2, 3])
#       2 print(my_frozen_set)
# ----> 3 my_frozen_set.add(4)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
langs = {"C", "C++", "Java", "Python"}
for lang in langs:
   print (lang)
# Out:
# C
# C++
# Python
# Java

# %%
my_set = {1, 2, 3, 4, 5}
accessed_items = [item for item in my_set]
print(accessed_items)
# Out:
# [1, 2, 3, 4, 5]

# %%
language = set()
language.add("C")
language.add("C++")
language.add("Java")
language.add("Python")
print("Updated Set:", language)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 language = set()
#       2 language.add("C")
#       3 language.add("C++")
#
# TypeError: 'set' object is not callable

# %%
my_set = {1, 2, 3}
print("Updated Set:", my_set)
# Out:
# Updated Set: {1, 2, 3}

# %%
my_set = {"Rohan", "Physics", 21, 69.75}
print ("Original set: ", my_set)

my_set.remove("Physics")
print ("Set after removing: ", my_set)
# Out:
# Original set:  {21, 'Rohan', 69.75, 'Physics'}
# Set after removing:  {21, 'Rohan', 69.75}

# %%
my_set = {"Rohan", "Physics", 21, 69.75}
print ("Original set: ", my_set)

my_set.remove("PHP")
print ("Set after removing: ", my_set)
# Out:
# Original set:  {'Rohan', 69.75, 21, 'Physics'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       1 my_set = {"Rohan", "Physics", 21, 69.75}
#       2 print ("Original set: ", my_set)
# ----> 4 my_set.remove("PHP")
#       5 print ("Set after removing: ", my_set)
#
# KeyError: 'PHP'

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
print ("s1: ", s1, "s2: ", s2)
s3 = s1.symmetric_difference(s2)
print ("s1 = s1^s2 ", s3)
# Out:
# s1:  {1, 2, 3, 4, 5} s2:  {4, 5, 6, 7, 8}
# s1 = s1^s2  {1, 2, 3, 6, 7, 8}

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
print ("s1: ", s1, "s2: ", s2)
s1.symmetric_difference_update(s2)
print ("s1 after running symmetric difference ", s1)
# Out:
# s1:  {1, 2, 3, 4, 5} s2:  {4, 5, 6, 7, 8}
# s1 after running symmetric difference  {1, 2, 3, 6, 7, 8}

# %%
my_set = {1, 2, 3, 4, 5}
set_list = list(my_set)
for index, item in enumerate(set_list):
   print("Index:", index, "Item:", item)
# Out:
# Index: 0 Item: 1
# Index: 1 Item: 2
# Index: 2 Item: 3
# Index: 3 Item: 4
# Index: 4 Item: 5

# %%
my_set = set()  
for i in range(5):
   my_set.add(i)
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 my_set = set()
#       2 for i in range(5):
#       3    my_set.add(i)
#
# TypeError: 'set' object is not callable

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s3 = s1|s2
print (s3)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s3 = s1.union(s2)
print (s3)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s3 = {*s1, *s2}
print (s3)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
